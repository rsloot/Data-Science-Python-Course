# %%
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage import data

photo = misc.imread('TRAPPIST-1e_PRINT_E.jpg')

# %%
plt.figure(figsize=(15,15))
plt.imshow(photo)

# %% [markdown]
# ### Red to blue, blue to red

# %%
from random import randint
photo = misc.imread('TRAPPIST-1e_PRINT_E.jpg')
red_filter = photo[:,:,0] > 220
# blue_filter = photo[:,:,2] > 150
r = randint(0,photo.shape[0])
print(r)
photo[red_filter] = 0#[photo[r][0][2],photo[r][0][1], photo[r][0][0]]
# photo[blue_filter] = [200,50,50]
plt.figure(figsize=(10,10))
plt.imshow(photo)
# Out:
# 1089

# %%
[photo[red_filter][r][2],photo[red_filter][r][1], photo[red_filter][r][0]]
# Out:
# [230, 228, 216]

# %%
from random import randint
randint(-1,4)
# Out:
# 0

# %%
photo[0][2]
# Out:
# array([161, 171, 207], dtype=uint8)
